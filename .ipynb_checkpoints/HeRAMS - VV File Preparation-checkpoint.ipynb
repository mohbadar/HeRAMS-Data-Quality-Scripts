# %% [markdown]
# # Import Libraries

# %%
# Library Import
import pandas as pd
from datetime import datetime
now = datetime.now()

import random
import string

# %% [markdown]
# # Import Data

# %%
df = pd.read_excel('vv/raw_input.xlsx',sheet_name='Sheet1')
# Read top 5 records to check the data 
df.head()
# Out:
#    id submitdate  lastpage startlanguage            token  startdate  \
# 0   5 2023-10-19        16            en  6c6RTtz1XJaiWKW 2023-10-19
# 1   2 2023-10-19        16            en  6c6RTtz1XJaiWKW 2023-10-19
# 2   6 2023-10-19        16            en  1T16p29Z5FR4hgq 2023-10-19
# 3   7 2023-10-19        16            en  1T16p29Z5FR4hgq 2023-10-19
# 4   8 2023-10-19        16            en  1T16p29Z5FR4hgq 2023-10-19
#
#    datestamp     Update   UOID  MoSD1  ... QHeRAMS511x[3] QHeRAMS512  \
# 0 2023-10-19 2023-10-19  D9R1E    NaN  ...             A4         A3
# 1 2023-10-19 2023-10-19  X5J0S    NaN  ...             A3         A4
# 2 2023-10-19 2023-10-19  E7O3N    NaN  ...             A4         A4
# 3 2023-10-19 2023-10-19  Q4Q2E    NaN  ...            NaN         A4
# 4 2023-10-19 2023-10-19    NaN    NaN  ...            NaN         A4
#
#    QHeRAMS512x[1]  QHeRAMS512x[2] QHeRAMS512x[3] QHeRAMS513  QHeRAMS513x[1]  \
# 0              A4              A3            NaN         A1             NaN
# 1             NaN             NaN            NaN         A1             NaN
# 2             NaN             NaN            NaN         A4             NaN
# 3             NaN             NaN            NaN         A1             NaN
# 4             NaN             NaN            NaN         A2              A3
#
#   QHeRAMS513x[2]  QHeRAMS513x[3] ENR
# 0            NaN             NaN NaN
# 1            NaN             NaN NaN
# 2            NaN             NaN NaN
# 3            NaN             NaN NaN
# 4            NaN             NaN NaN
#
# [5 rows x 563 columns]

# %%
df.shape
# Out:
# (49, 563)

# %% [markdown]
# # Data Cleaning and Exploration

# %%
# Drop rows where MoSD2 is missing
df = df.dropna(subset=['MoSD2'])

# Reset index for dropped rows
df.reset_index(inplace=True, drop=True)

# %%
df.rename(columns=lambda s: s.replace("[", "_"), inplace=True)
df.rename(columns=lambda s: s.replace("]", ""), inplace=True)

# %%
# Convert and format the Date columns
df['startdate'] = pd.to_datetime(df['startdate']).dt.strftime('%Y-%m-%d %H:%M:%S')
df['submitdate'] = pd.to_datetime(df['submitdate']).dt.strftime('%Y-%m-%d %H:%M:%S')
df['datestamp'] = pd.to_datetime(df['datestamp']).dt.strftime('%Y-%m-%d %H:%M:%S')
df['Update'] = pd.to_datetime(df['Update']).dt.strftime('%Y-%m-%d %H:%M:%S')

df.head()
# Out:
#    id           submitdate  lastpage startlanguage            token  \
# 0   8  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 1   9  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 2  10  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 3  12  2023-10-19 00:00:00        16            en  42UOMVDsP8y84ut
# 4  13  2023-10-19 00:00:00        16            en  42UOMVDsP8y84ut
#
#              startdate            datestamp               Update UOID  MoSD1  \
# 0  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 1  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 2  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 3  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 4  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
#
#    ... QHeRAMS511x_3 QHeRAMS512  QHeRAMS512x_1  QHeRAMS512x_2 QHeRAMS512x_3  \
# 0  ...           NaN         A4            NaN            NaN           NaN
# 1  ...           NaN        NaN            NaN            NaN           NaN
# 2  ...           NaN        NaN            NaN            NaN           NaN
# 3  ...           NaN        NaN            NaN            NaN           NaN
# 4  ...           NaN        NaN            NaN            NaN           NaN
#
#   QHeRAMS513  QHeRAMS513x_1 QHeRAMS513x_2  QHeRAMS513x_3 ENR
# 0         A2             A3           NaN            NaN NaN
# 1        NaN            NaN           NaN            NaN NaN
# 2        NaN            NaN           NaN            NaN NaN
# 3        NaN            NaN           NaN            NaN NaN
# 4        NaN            NaN           NaN            NaN NaN
#
# [5 rows x 563 columns]

# %%
# The new size of df
print(df.shape)
print("(Row x Column)")

df.to_csv('vv/test.csv')
# Out:
# (34, 563)
# (Row x Column)

# %%
# See the overall HFs by Type 

# Group by Hf Type
dfg = df.groupby(['MoSD3']).size()

# Plot
dfg.plot(kind='bar', ylabel='HF Count',
         xlabel='HF Type', figsize=(10, 6), subplots=True)
# Out:
# array([<Axes: xlabel='HF Type', ylabel='HF Count'>], dtype=object)

# %%
def generate_random_code():
    return ''.join([
        random.choice(string.ascii_uppercase),
        str(random.randint(0, 9)),
        random.choice(string.ascii_uppercase),
        str(random.randint(0, 9)),
        random.choice(string.ascii_uppercase)
    ])

# Example usage:
# random_string = generate_random_code()
# print(random_string)

# %%
import numpy as np

def is_string_empty_or_null(s):
    return s is None or s == '' or s == np.nan

# %%
# df['Column1'] = df['Column1'].replace('', 'specified_value').fillna('specified_value')

for index, row in df.iterrows():
    if(row['UOID']):
        print(index)
    elif
        df.at[index, 'UOID'] = generate_random_code()
        
        
df.head()
# Out:
#    id           submitdate  lastpage startlanguage            token  \
# 0   8  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 1   9  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 2  10  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 3  12  2023-10-19 00:00:00        16            en  42UOMVDsP8y84ut
# 4  13  2023-10-19 00:00:00        16            en  42UOMVDsP8y84ut
#
#              startdate            datestamp               Update UOID  MoSD1  \
# 0  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 1  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 2  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 3  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 4  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
#
#    ... QHeRAMS511x_3 QHeRAMS512  QHeRAMS512x_1  QHeRAMS512x_2 QHeRAMS512x_3  \
# 0  ...           NaN         A4            NaN            NaN           NaN
# 1  ...           NaN        NaN            NaN            NaN           NaN
# 2  ...           NaN        NaN            NaN            NaN           NaN
# 3  ...           NaN        NaN            NaN            NaN           NaN
# 4  ...           NaN        NaN            NaN            NaN           NaN
#
#   QHeRAMS513  QHeRAMS513x_1 QHeRAMS513x_2  QHeRAMS513x_3 ENR
# 0         A2             A3           NaN            NaN NaN
# 1        NaN            NaN           NaN            NaN NaN
# 2        NaN            NaN           NaN            NaN NaN
# 3        NaN            NaN           NaN            NaN NaN
# 4        NaN            NaN           NaN            NaN NaN
#
# [5 rows x 563 columns]

# %%
# Out:
#    id           submitdate  lastpage startlanguage            token  \
# 0   8  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 1   9  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 2  10  2023-10-19 00:00:00        16            en  1T16p29Z5FR4hgq
# 3  12  2023-10-19 00:00:00        16            en  42UOMVDsP8y84ut
# 4  13  2023-10-19 00:00:00        16            en  42UOMVDsP8y84ut
#
#              startdate            datestamp               Update UOID  MoSD1  \
# 0  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 1  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 2  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 3  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
# 4  2023-10-19 00:00:00  2023-10-19 00:00:00  2023-10-19 00:00:00  NaN    NaN
#
#    ... QHeRAMS511x_3 QHeRAMS512  QHeRAMS512x_1  QHeRAMS512x_2 QHeRAMS512x_3  \
# 0  ...           NaN         A4            NaN            NaN           NaN
# 1  ...           NaN        NaN            NaN            NaN           NaN
# 2  ...           NaN        NaN            NaN            NaN           NaN
# 3  ...           NaN        NaN            NaN            NaN           NaN
# 4  ...           NaN        NaN            NaN            NaN           NaN
#
#   QHeRAMS513  QHeRAMS513x_1 QHeRAMS513x_2  QHeRAMS513x_3 ENR
# 0         A2             A3           NaN            NaN NaN
# 1        NaN            NaN           NaN            NaN NaN
# 2        NaN            NaN           NaN            NaN NaN
# 3        NaN            NaN           NaN            NaN NaN
# 4        NaN            NaN           NaN            NaN NaN
#
# [5 rows x 563 columns]

# %%
# df = df.replace('NaN', '{question_not_shown}')
# Replace NaN values with "{question_not_shown}"
df.fillna('{question_not_shown}', inplace=True)
# df.mask(df == '{question_not_shown}')
df.head()
